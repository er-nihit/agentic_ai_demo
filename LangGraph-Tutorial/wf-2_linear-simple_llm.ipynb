# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI(model='gpt-5-nano')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 load_dotenv()
# ----> 3 model = ChatOpenAI(model='gpt-5-nano')
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\base.py:1078, in BaseChatOpenAI.validate_environment(self)
#    1072         raise ImportError(msg) from e
#    1073     self.http_client = httpx.Client(
#    1074         proxy=self.openai_proxy, verify=global_ssl_context
#    1075     )
#    1076 sync_specific = {
#    1077     "http_client": self.http_client
# -> 1078     or _get_default_httpx_client(
#    1079         self.openai_api_base, self.request_timeout
#    1080     ),
#    1081     "api_key": sync_api_key_value,
#    1082 }
#    1083 self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#    1084 self.client = self.root_client.chat.completions
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:97, in _get_default_httpx_client(base_url, timeout)
#      95     return _build_sync_httpx_client(base_url, timeout)
#      96 else:
# ---> 97     return _cached_sync_httpx_client(base_url, timeout)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:75, in _cached_sync_httpx_client(base_url, timeout)
#      71 @lru_cache
#      72 def _cached_sync_httpx_client(
#      73     base_url: str | None, timeout: Any
#      74 ) -> _SyncHttpxClientWrapper:
# ---> 75     return _build_sync_httpx_client(base_url, timeout)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:52, in _build_sync_httpx_client(base_url, timeout)
#      49 def _build_sync_httpx_client(
#      50     base_url: str | None, timeout: Any
#      51 ) -> _SyncHttpxClientWrapper:
# ---> 52     return _SyncHttpxClientWrapper(
#      53         base_url=base_url
#      54         or os.environ.get("OPENAI_BASE_URL")
#      55         or "https://api.openai.com/v1",
#      56         timeout=timeout,
#      57     )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\openai\_base_client.py:822, in _DefaultHttpxClient.__init__(self, **kwargs)
#     820 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
#     821 kwargs.setdefault("follow_redirects", True)
# --> 822 super().__init__(**kwargs)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_client.py:688, in Client.__init__(self, auth, params, headers, cookies, verify, cert, trust_env, http1, http2, proxy, mounts, timeout, follow_redirects, limits, max_redirects, event_hooks, base_url, transport, default_encoding)
#     685 allow_env_proxies = trust_env and transport is None
#     686 proxy_map = self._get_proxy_map(proxy, allow_env_proxies)
# --> 688 self._transport = self._init_transport(
#     689     verify=verify,
#     690     cert=cert,
#     691     trust_env=trust_env,
#     692     http1=http1,
#     693     http2=http2,
#     694     limits=limits,
#     695     transport=transport,
#     696 )
#     697 self._mounts: dict[URLPattern, BaseTransport | None] = {
#     698     URLPattern(key): None
#     699     if proxy is None
#    (...)
#     709     for key, proxy in proxy_map.items()
#     710 }
#     711 if mounts is not None:
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_client.py:731, in Client._init_transport(self, verify, cert, trust_env, http1, http2, limits, transport)
#     728 if transport is not None:
#     729     return transport
# --> 731 return HTTPTransport(
#     732     verify=verify,
#     733     cert=cert,
#     734     trust_env=trust_env,
#     735     http1=http1,
#     736     http2=http2,
#     737     limits=limits,
#     738 )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_transports\default.py:153, in HTTPTransport.__init__(self, verify, cert, trust_env, http1, http2, limits, proxy, uds, local_address, retries, socket_options)
#     150 import httpcore
#     152 proxy = Proxy(url=proxy) if isinstance(proxy, (str, URL)) else proxy
# --> 153 ssl_context = create_ssl_context(verify=verify, cert=cert, trust_env=trust_env)
#     155 if proxy is None:
#     156     self._pool = httpcore.ConnectionPool(
#     157         ssl_context=ssl_context,
#     158         max_connections=limits.max_connections,
#    (...)
#     166         socket_options=socket_options,
#     167     )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_config.py:35, in create_ssl_context(verify, cert, trust_env)
#      33 if verify is True:
#      34     if trust_env and os.environ.get("SSL_CERT_FILE"):  # pragma: nocover
# ---> 35         ctx = ssl.create_default_context(cafile=os.environ["SSL_CERT_FILE"])
#      36     elif trust_env and os.environ.get("SSL_CERT_DIR"):  # pragma: nocover
#      37         ctx = ssl.create_default_context(capath=os.environ["SSL_CERT_DIR"])
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\ssl.py:766, in create_default_context(purpose, cafile, capath, cadata)
#     763     raise ValueError(purpose)
#     765 if cafile or capath or cadata:
# --> 766     context.load_verify_locations(cafile, capath, cadata)
#     767 elif context.verify_mode != CERT_NONE:
#     768     # no explicit cafile, capath or cadata but the verify mode is
#     769     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     770     # root CA certificates for the given purpose. This may fail silently.
#     771     context.load_default_certs(purpose)
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def ask_llm(state: LLMState) -> LLMState:

    state['answer'] = model.invoke(state['question']).content

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('ask_llm', ask_llm)

graph.add_edge(START, 'ask_llm')
graph.add_edge('ask_llm',END)

workflow = graph.compile()

# %%
workflow.invoke({'question':'What is capital of India'})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 workflow.invoke({'question':'What is capital of India'})
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\pregel\main.py:3365, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3362             chunks.append(chunk)
#    3363 else:
#    3364     # v1: collect interrupts from updates stream
# -> 3365     for chunk in self.stream(
#    3366         input,
#    3367         config,
#    3368         context=context,
#    3369         stream_mode=(
#    3370             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3371         ),
#    3372         print_mode=print_mode,
#    3373         output_keys=output_keys,
#    3374         interrupt_before=interrupt_before,
#    3375         interrupt_after=interrupt_after,
#    3376         durability=durability,
#    3377         **kwargs,
#    3378     ):
#    3379         if stream_mode == "values":
#    3380             if len(chunk) == 2:
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\pregel\main.py:2759, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2757 for task in loop.match_cached_writes():
#    2758     loop.output_writes(task.id, task.writes, cached=True)
# -> 2759 for _ in runner.tick(
#    2760     [t for t in loop.tasks.values() if not t.writes],
#    2761     timeout=self.step_timeout,
#    2762     get_waiter=get_waiter,
#    2763     schedule_task=loop.accept_push,
#    2764 ):
#    2765     # emit output
#    2766     yield from _output(
#    2767         stream_mode,
#    2768         print_mode,
#    (...)
#    2774         _state_mapper,
#    2775     )
#    2776 loop.after_tick()
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\pregel\_retry.py:126, in run_with_retry(task, retry_policy, configurable)
#     124     task.writes.clear()
#     125     # run the task
# --> 126     return task.proc.invoke(task.input, config)
#     127 except ParentCommand as exc:
#     128     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[14], line 2, in ask_llm(state)
#       1 def ask_llm(state: LLMState) -> LLMState:
# ----> 2     model = ChatOpenAI()
#       4     state['answer'] = model.invoke(state['question']).content
#       6     return state
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\base.py:1078, in BaseChatOpenAI.validate_environment(self)
#    1072         raise ImportError(msg) from e
#    1073     self.http_client = httpx.Client(
#    1074         proxy=self.openai_proxy, verify=global_ssl_context
#    1075     )
#    1076 sync_specific = {
#    1077     "http_client": self.http_client
# -> 1078     or _get_default_httpx_client(
#    1079         self.openai_api_base, self.request_timeout
#    1080     ),
#    1081     "api_key": sync_api_key_value,
#    1082 }
#    1083 self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#    1084 self.client = self.root_client.chat.completions
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:97, in _get_default_httpx_client(base_url, timeout)
#      95     return _build_sync_httpx_client(base_url, timeout)
#      96 else:
# ---> 97     return _cached_sync_httpx_client(base_url, timeout)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:75, in _cached_sync_httpx_client(base_url, timeout)
#      71 @lru_cache
#      72 def _cached_sync_httpx_client(
#      73     base_url: str | None, timeout: Any
#      74 ) -> _SyncHttpxClientWrapper:
# ---> 75     return _build_sync_httpx_client(base_url, timeout)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\langchain_openai\chat_models\_client_utils.py:52, in _build_sync_httpx_client(base_url, timeout)
#      49 def _build_sync_httpx_client(
#      50     base_url: str | None, timeout: Any
#      51 ) -> _SyncHttpxClientWrapper:
# ---> 52     return _SyncHttpxClientWrapper(
#      53         base_url=base_url
#      54         or os.environ.get("OPENAI_BASE_URL")
#      55         or "https://api.openai.com/v1",
#      56         timeout=timeout,
#      57     )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\openai\_base_client.py:822, in _DefaultHttpxClient.__init__(self, **kwargs)
#     820 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
#     821 kwargs.setdefault("follow_redirects", True)
# --> 822 super().__init__(**kwargs)
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_client.py:688, in Client.__init__(self, auth, params, headers, cookies, verify, cert, trust_env, http1, http2, proxy, mounts, timeout, follow_redirects, limits, max_redirects, event_hooks, base_url, transport, default_encoding)
#     685 allow_env_proxies = trust_env and transport is None
#     686 proxy_map = self._get_proxy_map(proxy, allow_env_proxies)
# --> 688 self._transport = self._init_transport(
#     689     verify=verify,
#     690     cert=cert,
#     691     trust_env=trust_env,
#     692     http1=http1,
#     693     http2=http2,
#     694     limits=limits,
#     695     transport=transport,
#     696 )
#     697 self._mounts: dict[URLPattern, BaseTransport | None] = {
#     698     URLPattern(key): None
#     699     if proxy is None
#    (...)
#     709     for key, proxy in proxy_map.items()
#     710 }
#     711 if mounts is not None:
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_client.py:731, in Client._init_transport(self, verify, cert, trust_env, http1, http2, limits, transport)
#     728 if transport is not None:
#     729     return transport
# --> 731 return HTTPTransport(
#     732     verify=verify,
#     733     cert=cert,
#     734     trust_env=trust_env,
#     735     http1=http1,
#     736     http2=http2,
#     737     limits=limits,
#     738 )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_transports\default.py:153, in HTTPTransport.__init__(self, verify, cert, trust_env, http1, http2, limits, proxy, uds, local_address, retries, socket_options)
#     150 import httpcore
#     152 proxy = Proxy(url=proxy) if isinstance(proxy, (str, URL)) else proxy
# --> 153 ssl_context = create_ssl_context(verify=verify, cert=cert, trust_env=trust_env)
#     155 if proxy is None:
#     156     self._pool = httpcore.ConnectionPool(
#     157         ssl_context=ssl_context,
#     158         max_connections=limits.max_connections,
#    (...)
#     166         socket_options=socket_options,
#     167     )
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\httpx\_config.py:35, in create_ssl_context(verify, cert, trust_env)
#      33 if verify is True:
#      34     if trust_env and os.environ.get("SSL_CERT_FILE"):  # pragma: nocover
# ---> 35         ctx = ssl.create_default_context(cafile=os.environ["SSL_CERT_FILE"])
#      36     elif trust_env and os.environ.get("SSL_CERT_DIR"):  # pragma: nocover
#      37         ctx = ssl.create_default_context(capath=os.environ["SSL_CERT_DIR"])
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\ssl.py:766, in create_default_context(purpose, cafile, capath, cadata)
#     763     raise ValueError(purpose)
#     765 if cafile or capath or cadata:
# --> 766     context.load_verify_locations(cafile, capath, cadata)
#     767 elif context.verify_mode != CERT_NONE:
#     768     # no explicit cafile, capath or cadata but the verify mode is
#     769     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     770     # root CA certificates for the given purpose. This may fail silently.
#     771     context.load_default_certs(purpose)
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
mode
