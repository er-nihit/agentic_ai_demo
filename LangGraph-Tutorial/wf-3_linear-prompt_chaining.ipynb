# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI(model='gpt-5-nano')

# %%
class BlogState(TypedDict):
    topic: str
    outline: str
    blog: str

# %%
def create_outline(state: BlogState) -> BlogState:
    topic = state['topic']

    prompt = f"Create a outline for a blog on {topic}"

    result = model.invoke(prompt)

    state['outline'] = result.content

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    outline = state['outline']

    prompt = f"Create a blog on the mentioned outline  \n {outline}"

    result = model.invoke(prompt)

    state['blog'] = result.content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'topic': 'Recession'}

final_state = workflow.invoke(initial_state)

# %%
final_state
# Out:
# {'topic': 'Recession',
#  'outline': 'I. Introduction\n    A. Definition of recession\n    B. History of recessions in the economy\n    C. Impact of recessions on businesses and individuals\n\nII. Signs of a Recession\n    A. Decrease in GDP\n    B. Rising unemployment rates \n    C. Decline in consumer spending \n\nIII. Causes of Recession\n    A. Excessive debt levels\n    B. Asset bubbles \n    C. External factors (global economic downturn, pandemics)\n\nIV. Effects of Recession\n    A. Job losses\n    B. Bankruptcies and closures of businesses \n    C. Housing market crashes \n\nV. Strategies to Navigate a Recession\n    A. Diversifying investments\n    B. Cutting costs and expenses \n    C. Seeking new opportunities \n\nVI. Government Interventions during Recession\n    A. Fiscal policy (stimulus packages, tax cuts)\n    B. Monetary policy (interest rate cuts)\n    C. Bailouts for struggling industries \n\nVII. Lessons Learned from Past Recessions\n    A. Importance of risk management \n    B. Building a strong financial foundation \n    C. Adapting to changing market conditions \n\nVIII. Conclusion \n    A. Recap of key points \n    B. Encouragement for readers facing a recession \n    C. Resources for further information on navigating a recession.',
#  'blog': "In today's uncertain economic climate, the word recession is frequently brought up in discussions about the state of the economy. But what exactly is a recession, and how does it impact businesses and individuals alike? In this blog, we will explore the various aspects of a recession, from its signs and causes to its effects and strategies for navigating through it.\n\nI. Introduction\n\nA. Definition of recession\n\nA recession is defined as a period of temporary economic decline characterized by a decrease in GDP (Gross Domestic Product) for two consecutive quarters.\n\nB. History of recessions in the economy\n\nRecessions have been a recurring feature of the economy over the years, with notable recessions such as the Great Depression in the 1930s and the Global Financial Crisis in 2008.\n\nC. Impact of recessions on businesses and individuals\n\nRecessions can lead to job losses, bankruptcies, and a decline in consumer spending, affecting businesses and individuals alike.\n\nII. Signs of a Recession\n\nA. Decrease in GDP\n\nA decrease in GDP for two consecutive quarters is a key indicator of a recession.\n\nB. Rising unemployment rates\n\nUnemployment rates tend to rise during a recession as businesses cut costs and lay off employees.\n\nC. Decline in consumer spending\n\nConsumers tend to spend less during a recession, leading to a decline in retail sales and other consumer-driven sectors.\n\nIII. Causes of Recession\n\nA. Excessive debt levels\n\nHigh levels of debt can strain the economy and lead to a recession.\n\nB. Asset bubbles\n\nSpeculative bubbles in assets such as housing or stocks can burst, triggering a recession.\n\nC. External factors\n\nGlobal economic downturns, pandemics, and other external factors can also contribute to a recession.\n\nIV. Effects of Recession\n\nA. Job losses\n\nJob losses are a common effect of a recession, as businesses cut costs to survive.\n\nB. Bankruptcies and closures of businesses\n\nMany businesses may struggle to stay afloat during a recession, leading to bankruptcies and closures.\n\nC. Housing market crashes\n\nHousing markets can crash during a recession, leading to foreclosures and a decline in property values.\n\nV. Strategies to Navigate a Recession\n\nA. Diversifying investments\n\nDiversifying investments can help protect against losses during a recession.\n\nB. Cutting costs and expenses\n\nCutting costs and expenses can help businesses weather the storm during a recession.\n\nC. Seeking new opportunities\n\nFinding new opportunities and adapting to changing market conditions can help individuals and businesses navigate a recession.\n\nVI. Government Interventions during Recession\n\nA. Fiscal policy\n\nGovernments often implement stimulus packages and tax cuts to stimulate the economy during a recession.\n\nB. Monetary policy\n\nCentral banks may lower interest rates to boost economic activity during a recession.\n\nC. Bailouts for struggling industries\n\nGovernments may provide bailouts to struggling industries to prevent widespread economic damage.\n\nVII. Lessons Learned from Past Recessions\n\nA. Importance of risk management\n\nEffective risk management strategies can help businesses mitigate the impact of a recession.\n\nB. Building a strong financial foundation\n\nHaving a strong financial foundation can help individuals weather the storm during a recession.\n\nC. Adapting to changing market conditions\n\nAdapting to changing market conditions and finding new opportunities can help businesses survive and thrive during a recession.\n\nVIII. Conclusion\n\nIn conclusion, recessions are a natural part of the economic cycle, and understanding their signs, causes, and effects can help individuals and businesses prepare for and navigate through these challenging times. By implementing strategies such as diversifying investments, cutting costs, and seeking new opportunities, as well as learning from past recessions, we can emerge stronger and more resilient  ...
