# %% [markdown]
# # Youtube Summarizer
# ---
# - **Author**: Nihit Kumar
# - **Created**: April 20, 2026
# - **Description**: This project aims to fetch transcript from a Youtube video and store the transcript as embeddings. User can chat and ask the AI chatbot about the video to get the required results explained from the video.
# ---
# **This code is currently not working because my IP has been banned by Youtube** :(

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ### 1. Indexing

# %%
# Get youtube link/ID from the user
# Video ID is the value between 'v=' and '?' in the link
video_link = "https://www.youtube.com/watch?v=0wPe2pkwVfY"
video_id = "LPZh9BOjkQs"


try:
    # This block will check if the transcripts are enabled for the video
    #transcript_list = YouTubeTranscriptApi().fetch(video_id)

    # Merge the automatically generated chunks into a single string
    transcript = " ".join(chunk['text'] for chunk in transcript_list)
    print(transcript)

except:
    # If the video does not have captions enabled, it will throw this error
    print("No captions enabled for this video")
# Out:
# No captions enabled for this video

# %%
## DO NOT RUN THIS CELLS VERY FREQUENTLY.
## IP WILL BE BANNED FOR TOO MANY FREQUENT API CALLS

video_id = "UabBYexBD4k"
#transcript_list = YouTubeTranscriptApi().fetch(video_id=video_id)
transcript_list.video_id
# Out:
# ---------------------------------------------------------------------------
# IpBlocked                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 ## DO NOT RUN THIS CELLS VERY FREQUENTLY.
#       2 ## IP WILL BE BANNED FOR TOO MANY FREQUENT API CALLS
#       4 video_id = "UabBYexBD4k"
# ----> 5 transcript_list = YouTubeTranscriptApi().fetch(video_id=video_id)
#       6 transcript_list.video_id
#
# File c:\Users\asus\.conda\envs\ai-agents\lib\site-packages\youtube_transcript_api\_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      51 def fetch(
#      52     self,
#      53     video_id: str,
#      54     languages: Iterable[str] = ("en",),
#      55     preserve_formatting: bool = False,
#      56 ) -> FetchedTranscript:
#      57     """
#      58     Retrieves the transcript for a single video. This is just a shortcut for
#      59     calling:
#    (...)
# ...
